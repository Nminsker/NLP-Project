# %%
# !pip install datasets
# !pip install sentence-transformers

# %%
# from google.colab import drive # uncomment if you are using google colab

import math
import matplotlib.pyplot as plt

import os

import torch
from torch.utils.data import DataLoader
from sentence_transformers import SentenceTransformer, InputExample, models, losses
from sentence_transformers.evaluation import EmbeddingSimilarityEvaluator

import pandas as pd

import warnings

warnings.filterwarnings("ignore")

# %%
# drive.mount('/content/drive') # mount google drive when not local

# %% [markdown]
# # Data Load & Preperation

# %% [markdown]
# ## Constants

# %%
# # on colab
# DATA_PATH = "/content/drive/MyDrive/HebNLI"
# MODEL_DIR = "/content/drive/MyDrive/SBERT_Models"

# Local
DATA_PATH = "Data"
MODEL_DIR = "SBERT_Models"

BATCH_SIZE = 16

# %% [markdown]
# ## Data preprocessing

# %%
def prepare_data(fileName, lableAsFloat=False) -> tuple:
    """ Given a path for a dataframe, return both a datframe with columns = [translation1, translation2, original_label] and a list of InputExamples """
    LABEL_MAP = {
        'contradiction': 0.0 if lableAsFloat else 0,
        'neutral': 0.5 if lableAsFloat else 1,
        'entailment': 1.0 if lableAsFloat else 2,
    }
    
    df = pd.read_json(f"{DATA_PATH}/{fileName}", lines=True)

    df.dropna(inplace=True)
    df = df[df.original_label != '-']

    df["label"] = df["original_label"].apply(lambda x: LABEL_MAP[x.lower()],)
    df = df["translation1 translation2 label".split()]

    examples = [
        InputExample(texts=[row.translation1, row.translation2], label=row.label)
        for _, row in df.iterrows()
    ]
    return df, examples

# %%
# Loading the data if needed

# train_df, train_examples = prepare_data("HebNLI_train.jsonl")
# dev_df, dev_examples = prepare_data("HebNLI_val.jsonl")
# test_df, test_examples = prepare_data("HebNLI_test.jsonl")

# %% [markdown]
# # Model Definition

# %%
class SBERT:
    def __init__(self, modelName, baseModelName, outputPath=MODEL_DIR):
        """
        modelName: str, short/pretty name
        baseModelName: str, model name as of huggingface
        outputPath: str, prefix for saving the model
        """
        self.modelName = modelName 
        self.baseModelName = baseModelName 
        self.outputPath = outputPath 

        self.setDevice()
        self.setOrGetModel()

    def setDevice(self):
        """ Set the torch.device based on the system capabilities """
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        print(f"Using device: {self.device}")

        # Setting seed for consistent results
        torch.manual_seed(42)
        if self.device == "cuda":
            torch.cuda.manual_seed_all(42)

    def setOrGetModel(self):
        """ If the model exists, load it. Otherwise, create a new model """

        fullPath = f"{self.outputPath}/{self.modelName}"

        if not os.path.exists(f"{fullPath}/config.json"):
            print(f"Couldn't find existing model: {self.modelName}, creating it.") 

            self._wordEmbeddingModel = models.Transformer(self.baseModelName)
            self._poolingModel = models.Pooling(self._wordEmbeddingModel.get_word_embedding_dimension())
            self.model = SentenceTransformer(modules=[self._wordEmbeddingModel, self._poolingModel], device=self.device) 
        else:
            print(f"Loading existing model: {self.modelName}")
            
            self.model = SentenceTransformer(fullPath)

    def train(self, trainDataloader, devExamples, numEpochs=1, learningRate=2e-5, useCosineLoss=True):
        """
            trainDataloader: DataLoader, for training
            devExamples: list of InputExamples, for validation
            numEpochs: int, number of epochs to train
            learningRate: float, learning rate for the optimizer
            useCosineLoss: bool, if True, use cosine loss. Otherwise, use softmax loss
        """
        print(f"\nTraining model: {self.modelName}")

        # Define the Loss function
        trainLoss = losses.CosineSimilarityLoss(self.model) if useCosineLoss else losses.SoftmaxLoss(
            model=self.model,
            sentence_embedding_dimension=self.model.get_sentence_embedding_dimension(),
            num_labels=3,
        )

        # Evaluator
        evaluator = EmbeddingSimilarityEvaluator.from_input_examples(devExamples, name='devExamples')

        # Configure the training
        warmupSteps = math.ceil(len(trainDataloader) * numEpochs * 0.1)  # 10% of train data for warm-up
        print(f"Warmup-steps: {warmupSteps}")

        # Train the model
        print(f"Starting training for {self.modelName}...")

        self.model.fit(
            train_objectives=[(trainDataloader, trainLoss)],
            evaluator=evaluator,
            epochs=numEpochs,
            evaluation_steps=1000,
            warmup_steps=warmupSteps,
            output_path=self.outputPath,
            optimizer_params={'lr': learningRate},
            show_progress_bar=True
        )

    def evaluate(self, test_examples, save=False):
        """ Evaluate the model on the test set and return the results. If save=True, save the results to a csv file
            test_examples: list of InputExamples, for testing. InputExample expected to have 2 sentences and a similarity score in the range 0-5 (float)
        """
        print(f"Evaluating model: {self.modelName}")
        
        # Evaluate on the test set
        testEvaluator = EmbeddingSimilarityEvaluator.from_input_examples(test_examples, name="")
        result = testEvaluator(self.model)

        if save: # Adds a row for the model with similarity results
            df = pd.read_csv("Results/STS_results.csv")
            df = pd.concat([df, pd.DataFrame.from_records([dict(Model=self.modelName, **result)])], ignore_index=True)
            df.to_csv("Results/STS_results.csv", index=False)
        return result

# %%
# Experiments configurations

configs = {
        "AlephBERT_1_epoch": {
            "baseModelName": "onlplab/alephbert-base",
            "trainKwargs": {
                "epochs": 1,
                "learningRate": 2e-5,
                "useCosineLoss": True
            }
        },
        "AlephBERT_3_epoch": {
            "baseModelName": "onlplab/alephbert-base",
            "trainKwargs": {
                "epochs": 3,
                "learningRate": 2e-5,
                "useCosineLoss": True
            }
        },
        "AlephBERT-softmax": {
            "baseModelName": "onlplab/alephbert-base",
            "trainKwargs": {
                "epochs": 1,
                "learningRate": 2e-5,
                "useCosineLoss": False
            }
        },
        "mBERT_1_epoch": {
            "baseModelName": "bert-base-multilingual-cased", 
            "trainKwargs": {
                "epochs": 1,
                "learningRate": 2e-5,
                "useCosineLoss": True
            }
        },
        "mBERT_3_epoch": {
            "baseModelName": "bert-base-multilingual-cased",
            "trainKwargs": {
                "epochs": 3,
                "learningRate": 2e-5,
                "useCosineLoss": True
            }
        },
        "mBERT-softmax": {
            "baseModelName": "bert-base-multilingual-cased",
            "trainKwargs": {
                "epochs": 1,
                "learningRate": 2e-5,
                "useCosineLoss": False
            }
        },
        "DictaBERT_1_epoch": {
            "baseModelName": "dicta-il/dictabert",
            "trainKwargs": {
                "epochs": 1,
                "learningRate": 2e-5,
                "useCosineLoss": True
            }
        },
        "DictaBERT_3_epoch": {
            "baseModelName": "dicta-il/dictabert",
            "trainKwargs": {
                "epochs": 3,
                "learningRate": 2e-5,
                "useCosineLoss": True
            }
        },
        "DictaBERT-softmax": {
            "baseModelName": "dicta-il/dictabert",
            "trainKwargs": {
                "epochs": 1,
                "learningRate": 2e-5,
                "useCosineLoss": False
            }
        }
    }

# %% [markdown]
# ### How to train

# %%
# Uncomment to train, change as needed

modelPrettyName = "AlephBERT_1_epoch"

model = SBERT(modelPrettyName, configs[modelPrettyName]["baseModelName"])
kwargs =  configs[modelPrettyName]["trainKwargs"]

train_df, train_examples = prepare_data("HebNLI_train.jsonl", kwargs["useCosineLoss"])
dev_df, dev_examples = prepare_data("HebNLI_val.jsonl", kwargs["useCosineLoss"])

train_dataloader = DataLoader(train_examples, shuffle=True,  batch_size=BATCH_SIZE)

model.train(train_dataloader, dev_examples, kwargs)

# %% [markdown]
# # How to load

# %%
sts_df  = pd.read_csv("Data/heb_sts_test.csv")
sts_examples = [
    InputExample(texts=[row.sentence1, row.sentence2], label=row.score)
    for _, row in sts_df.iterrows()
]

# %%
# for modelName, config in configs.items():
#     model = SBERT(modelName, config["baseModelName"])
#     model.evaluate(sts_examples, save=True)
#     del model

# %%
df = pd.read_csv("Results/STS_results.csv")
df
# Out:
#                  Model  pearson_cosine  spearman_cosine  pearson_manhattan  \
# 0    AlephBERT_1_epoch        0.691705         0.688564           0.700235
# 1    AlephBERT_3_epoch        0.648063         0.652879           0.663173
# 2    AlephBERT-softmax        0.481679         0.531122           0.525739
# 3        mBERT_1_epoch        0.542627         0.561740           0.529005
# 4        mBERT_3_epoch        0.479281         0.518612           0.501816
# 5        mBERT-softmax        0.304569         0.364991           0.342576
# 6    DictaBERT_1_epoch        0.709631         0.719112           0.718173
# 7    DictaBERT_3_epoch        0.647319         0.673221           0.681294
# 8    DictaBERT-softmax        0.354279         0.454970           0.453073
# 9   AlephBERT_baseline        0.669303         0.650824           0.642925
# 10  DictaBERT_baseline        0.590295         0.579988           0.561342
# ...

# %%
# baseline = []
# for modelName, baseline in (("AlephBERT_baseline", "onlplab/alephbert-base"), ("DictaBERT_baseline","bert-base-multilingual-cased"), ("mBERT_baseline", "dicta-il/dictabert")):
#     model = SBERT(modelName, baseline)
#     model.evaluate(sts_examples, save=True)
#     del model
# Out:
# Couldn't find existing model: AlephBERT_baseline, creating it.
# Some weights of BertModel were not initialized from the model checkpoint at onlplab/alephbert-base and are newly initialized: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating model: AlephBERT_baseline
# Couldn't find existing model: DictaBERT_baseline, creating it.
# Evaluating model: DictaBERT_baseline
# Couldn't find existing model: mBERT_baseline, creating it.
# Some weights of BertModel were not initialized from the model checkpoint at dicta-il/dictabert and are newly initialized: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluating model: mBERT_baseline

# %%
# Transposing the DataFrame so that models are the columns and metrics are the rows
df_transposed = df.set_index('Model').T

# Plotting with each line representing a model and each point representing a metric
df_transposed.plot(kind='line', marker='o', figsize=(14, 8))
plt.title('Model Metrics Comparison (Line Plot by Model)')
plt.ylabel('Metric Values')
plt.xlabel('Metric')
plt.xticks(rotation=45, ha="right")
plt.legend(title='Model', loc='upper left', bbox_to_anchor=(1, 1))
plt.tight_layout()
plt.show()

# %%
def plotByModels(df, regex):
    """
    df: pd.DataFrame, the dataframe with the results
    regex: str, the regex to filter the columns
    """
    # Transposing the DataFrame so that models are the columns and metrics are the rows
    baseline_df = df[df.Model.str.contains(regex)].set_index('Model').T
    # baseline_df = baseline_df.T
    # Plotting with each line representing a model and each point representing a metric
    baseline_df.plot(kind='line', marker='o', figsize=(14, 8))
    plt.title('Model Metrics Comparison (Line Plot by Model)')
    plt.ylabel('Metric Values')
    plt.xlabel('Metric')
    plt.xticks(ticks=range(len(baseline_df.index)), labels=baseline_df.index, rotation=45, ha="right")
    plt.legend(title='Model', loc='upper left', bbox_to_anchor=(1, 1))
    plt.tight_layout()
    plt.show()

# %%
plotByModels(df, "baseline")

# %%
plotByModels(df, "AlephBERT")

# %%
plotByModels(df, "mBERT")

# %%
plotByModels(df, "DictaBERT")

# %%
plotByModels(df, "1_epoch")
